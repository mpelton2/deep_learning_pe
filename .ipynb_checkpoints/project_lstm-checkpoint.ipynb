# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense,Activation
from keras.layers import LSTM
import pandas as pd
from numba import jit
import os

import warnings
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
from tensorflow.python.util import deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # lstm model

# %%
# input: sector name (sign: for calculating accurancy and prediction), number of epoch
# output: sector name (sign), rmse (mean squared error under squared root), prediction for input sector (yhat2)

def lstm_model(sign ,n_epoch=50):
    # convert series to supervised learning
    def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
        n_vars = 1 if type(data) is list else data.shape[1]
        df = DataFrame(data)
        cols, names = list(), list()
        # input sequence (t-n, ... t-1)
        for i in range(n_in, 0, -1):
            cols.append(df.shift(i))
            names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        # forecast sequence (t, t+1, ... t+n)
        for i in range(0, n_out):
            cols.append(df.shift(-i))
            if i == 0:
                names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
            else:
                names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
        # put it all together
        agg = concat(cols, axis=1)
        agg.columns = names
        # drop rows with NaN values
        if dropnan:
            agg.dropna(inplace=True)
        return agg
    
    #################### Divide data into train and test sets to calculate model accurancy ####################
    if sign == 'XLK':
        dataset = read_csv('data/data_XLK.csv', header=0, index_col=0)
        da1 = dataset[['Date','XLK']]
        da2 = dataset[['Date','GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLB','XLY','XLI','XLF','XLU','XLE','XLV','GSPC']]
    if sign == 'XLB':
        dataset = read_csv('data/data_XLB.csv', header=0, index_col=0)
        da1 = dataset[['Date','XLB']]
        da2 = dataset[['Date','GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLK','XLY','XLI','XLF','XLU','XLE','XLV','GSPC']]
    if sign == 'XLY':
        dataset = read_csv('data/data_XLY.csv', header=0, index_col=0)
        da1 = dataset[['Date','XLY']]
        da2 = dataset[['Date','GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLK','XLB','XLI','XLF','XLU','XLE','XLV','GSPC']]
    if sign == 'XLI':
        dataset = read_csv('data/data_XLI.csv', header=0, index_col=0)
        da1 = dataset[['Date','XLI']]
        da2 = dataset[['Date','GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLK','XLY','XLB','XLF','XLU','XLE','XLV','GSPC']]
    if sign == 'XLF':
        dataset = read_csv('data/data_XLF.csv', header=0, index_col=0)
        da1 = dataset[['Date','XLF']]
        da2 = dataset[['Date','GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLK','XLY','XLI','XLB','XLU','XLE','XLV','GSPC']]
    if sign == 'XLU':
        dataset = read_csv('data/data_XLU.csv', header=0, index_col=0)
        da1 = dataset[['Date','XLU']]
        da2 = dataset[['Date','GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLK','XLY','XLI','XLF','XLB','XLE','XLV','GSPC']]
    if sign == 'XLE':
        dataset = read_csv('data/data_XLE.csv', header=0, index_col=0)
        da1 = dataset[['Date','XLE']]
        da2 = dataset[['Date','GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLK','XLY','XLI','XLF','XLU','XLB','XLV','GSPC']]
    if sign == 'XLV':
        dataset = read_csv('data/data_XLV.csv', header=0, index_col=0)
        da1 = dataset[['Date','XLV']]
        da2 = dataset[['Date','GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLK','XLY','XLI','XLF','XLU','XLE','XLB','GSPC']]
    if sign == 'GSPC':
        dataset = read_csv('data/data_GSPC.csv', header=0, index_col=0)
        da1 = dataset[['Date','GSPC']]
        da2 = dataset[['Date','GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLK','XLY','XLI','XLF','XLU','XLE','XLV','XLB']]

    dataset = pd.merge(da1,da2,how='left',on='Date')
    dataset = dataset.drop(columns='Date')
    values = dataset.values

    # ensure all data is float
    values = values.astype('float32')
    # normalize features
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(values)
    n_lag = 1
    n_features = 15
    # frame as supervised learning
    reframed = series_to_supervised(scaled, n_lag, 1)
    #print(reframed.shape)

    # split into train and test sets, use first 
    values = reframed.values
    n_test_days = 1000
    #use first 1000 days to test, and remaining days to train
    train = values[:-n_test_days,:]
    test = values[-n_test_days:, :]
    # split into input and outputs
    n_obs = n_lag * n_features
    train_X, train_y = train[:, :n_obs], train[:, -n_features]
    test_X, test_y = test[:, :n_obs], test[:, -n_features]
    #print(train_X.shape, len(train_X), train_y.shape)
    # reshape input to be 3D [samples, timesteps, features]
    train_X = train_X.reshape((train_X.shape[0], n_lag, n_features))
    test_X = test_X.reshape((test_X.shape[0], n_lag, n_features))
    #print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
    
    # design network
    model = Sequential()
    model.add(LSTM(output_dim=50, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(1))
    model.add(Activation('tanh'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='mae', optimizer='adam')

    # fit network
    history = model.fit(train_X, train_y, epochs=n_epoch, batch_size=72, \
                        validation_data=(test_X, test_y), verbose=2, shuffle=False)
    # plot history
    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='test')
    pyplot.legend()
    pyplot.show()
    # make a prediction
    yhat = model.predict(test_X)
    # actual data
    test_y = test_y.reshape((len(test_y), 1))
    # calculate RMSE
    rmse = sqrt(mean_squared_error(test_y, yhat))
    
    
    ################################ Use all data to fit the model and predict ################################
    #use all data to fit network
    alldata = values[:, :]
    alldata_X, alldata_y = alldata[:, :n_obs], alldata[:, -n_features]
    alldata_X = alldata_X.reshape((alldata_X.shape[0], n_lag, n_features))
    
    # design network
    model = Sequential()
    model.add(LSTM(output_dim=50, input_shape=(alldata_X.shape[1], alldata_X.shape[2])))
    model.add(Dense(1))
    model.add(Activation('tanh'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='mae', optimizer='adam')
    history = model.fit(alldata_X, alldata_y, epochs=n_epoch, batch_size=72, \
                        verbose=2, shuffle=False)
    # load dataset to predict
    if sign == 'XLK':
        dataset = read_csv('future/X_future_XLK.csv', header=0, index_col=0)
        da = dataset[['GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLB','XLY','XLI','XLF','XLU','XLE','XLV','GSPC']]
    if sign == 'XLB':
        dataset = read_csv('future/X_future_XLB.csv', header=0, index_col=0)
        da = dataset[['GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLK','XLY','XLI','XLF','XLU','XLE','XLV','GSPC']]
    if sign == 'XLY':
        dataset = read_csv('future/X_future_XLY.csv', header=0, index_col=0)
        da = dataset[['GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLK','XLB','XLI','XLF','XLU','XLE','XLV','GSPC']]    
    if sign == 'XLI':
        dataset = read_csv('future/X_future_XLI.csv', header=0, index_col=0)
        da = dataset[['GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLK','XLY','XLB','XLF','XLU','XLE','XLV','GSPC']]
    if sign == 'XLF':
        dataset = read_csv('future/X_future_XLF.csv', header=0, index_col=0)
        da = dataset[['GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLK','XLY','XLI','XLB','XLU','XLE','XLV','GSPC']]
    if sign == 'XLU':
        dataset = read_csv('future/X_future_XLU.csv', header=0, index_col=0)
        da = dataset[['GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLK','XLY','XLI','XLF','XLB','XLE','XLV','GSPC']]
    if sign == 'XLE':
        dataset = read_csv('future/X_future_XLE.csv', header=0, index_col=0)
        da = dataset[['GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLK','XLY','XLI','XLF','XLU','XLB','XLV','GSPC']]
    if sign == 'XLV':
        dataset = read_csv('future/X_future_XLV.csv', header=0, index_col=0)
        da = dataset[['GDP','FEDFUNDS','LIBOR','MORTGAGE30US','REAL_USER_COST',\
                       'UNEMPLOYMENT_RT','XLK','XLY','XLI','XLF','XLU','XLE','XLB','GSPC']]
    dataset = da
    values = dataset.values
    # use future data to predict
    # ensure all data is float
    values = values.astype('float32')
    # normalize features
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(values)
    # frame as supervised learning
    reframed = series_to_supervised(scaled, n_lag, 1)
    #print(reframed.shape)

    # split into train and test sets, use first 
    values = reframed.values
    alldata = values[:, :]
    alldata_X= alldata[:, :n_obs]
    alldata_X = alldata_X.reshape((alldata_X.shape[0], n_lag, n_features))
    # make a prediction
    yhat2 = model.predict(alldata_X)
    # to get same dimension return result as DNN model, we add one result in the end
    yhat2=yhat2.T[0].tolist()
    yhat2.append(yhat2[-1])
    
    return sign,rmse,yhat2

# %%
output = lstm_model('XLK')
# Out:
# Train on 2577 samples, validate on 1000 samples
# Epoch 1/50
#  - 2s - loss: 0.2972 - val_loss: 0.1708
# Epoch 2/50
#  - 0s - loss: 0.2267 - val_loss: 0.2311
# Epoch 3/50
#  - 0s - loss: 0.1835 - val_loss: 0.2557
# Epoch 4/50
#  - 0s - loss: 0.1621 - val_loss: 0.2708
# Epoch 5/50
#  - 0s - loss: 0.1484 - val_loss: 0.2835
# Epoch 6/50
#  - 0s - loss: 0.1376 - val_loss: 0.2950
# Epoch 7/50
#  - 0s - loss: 0.1289 - val_loss: 0.3053
# Epoch 8/50
#  - 0s - loss: 0.1215 - val_loss: 0.3147
# Epoch 9/50
#  - 0s - loss: 0.1150 - val_loss: 0.3234
# Epoch 10/50
#  - 0s - loss: 0.1094 - val_loss: 0.3313
# Epoch 11/50
#  - 0s - loss: 0.1047 - val_loss: 0.3386
# Epoch 12/50
#  - 0s - loss: 0.1006 - val_loss: 0.3452
# Epoch 13/50
#  - 0s - loss: 0.0971 - val_loss: 0.3512
# Epoch 14/50
#  - 0s - loss: 0.0938 - val_loss: 0.3569
# Epoch 15/50
#  - 0s - loss: 0.0909 - val_loss: 0.3621
# Epoch 16/50
#  - 0s - loss: 0.0884 - val_loss: 0.3670
# Epoch 17/50
#  - 0s - loss: 0.0863 - val_loss: 0.3712
# Epoch 18/50
#  - 0s - loss: 0.0846 - val_loss: 0.3750
# Epoch 19/50
#  - 0s - loss: 0.0833 - val_loss: 0.3784
# Epoch 20/50
#  - 0s - loss: 0.0821 - val_loss: 0.3816
# Epoch 21/50
#  - 0s - loss: 0.0811 - val_loss: 0.3845
# Epoch 22/50
#  - 0s - loss: 0.0802 - val_loss: 0.3871
# Epoch 23/50
#  - 0s - loss: 0.0795 - val_loss: 0.3896
# Epoch 24/50
#  - 0s - loss: 0.0789 - val_loss: 0.3918
# Epoch 25/50
#  - 0s - loss: 0.0783 - val_loss: 0.3939
# Epoch 26/50
#  - 0s - loss: 0.0778 - val_loss: 0.3958
# Epoch 27/50
#  - 0s - loss: 0.0774 - val_loss: 0.3975
# Epoch 28/50
#  - 0s - loss: 0.0771 - val_loss: 0.3992
# Epoch 29/50
#  - 0s - loss: 0.0768 - val_loss: 0.4007
# Epoch 30/50
#  - 0s - loss: 0.0765 - val_loss: 0.4022
# Epoch 31/50
#  - 0s - loss: 0.0762 - val_loss: 0.4035
# Epoch 32/50
#  - 0s - loss: 0.0760 - val_loss: 0.4047
# Epoch 33/50
#  - 0s - loss: 0.0758 - val_loss: 0.4059
# Epoch 34/50
#  - 0s - loss: 0.0757 - val_loss: 0.4069
# Epoch 35/50
#  - 0s - loss: 0.0755 - val_loss: 0.4079
# Epoch 36/50
#  - 0s - loss: 0.0754 - val_loss: 0.4088
# Epoch 37/50
#  - 0s - loss: 0.0753 - val_loss: 0.4096
# Epoch 38/50
#  - 0s - loss: 0.0752 - val_loss: 0.4104
# Epoch 39/50
#  - 0s - loss: 0.0751 - val_loss: 0.4111
# Epoch 40/50
#  - 0s - loss: 0.0751 - val_loss: 0.4118
# Epoch 41/50
#  - 0s - loss: 0.0750 - val_loss: 0.4124
# Epoch 42/50
#  - 0s - loss: 0.0749 - val_loss: 0.4131
# Epoch 43/50
#  - 0s - loss: 0.0749 - val_loss: 0.4136
# Epoch 44/50
#  - 0s - loss: 0.0748 - val_loss: 0.4142
# Epoch 45/50
#  - 0s - loss: 0.0748 - val_loss: 0.4147
# Epoch 46/50
#  - 0s - loss: 0.0748 - val_loss: 0.4152
# Epoch 47/50
#  - 0s - loss: 0.0747 - val_loss: 0.4156
# Epoch 48/50
#  - 0s - loss: 0.0747 - val_loss: 0.4161
# Epoch 49/50
#  - 0s - loss: 0.0747 - val_loss: 0.4165
# Epoch 50/50
#  - 0s - loss: 0.0746 - val_loss: 0.4168
# Epoch 1/50
#  - 2s - loss: 0.2687
# Epoch 2/50
#  - 0s - loss: 0.2328
# Epoch 3/50
#  - 0s - loss: 0.2096
# Epoch 4/50
#  - 0s - loss: 0.1930
# Epoch 5/50
#  - 0s - loss: 0.1825
# Epoch 6/50
#  - 0s - loss: 0.1740
# Epoch 7/50
#  - 0s - loss: 0.1542
# Epoch 8/50
#  - 0s - loss: 0.1232
# Epoch 9/50
#  - 0s - loss: 0.1103
# Epoch 10/50
#  - 0s - loss: 0.0968
# Epoch 11/50
#  - 0s - loss: 0.0934
# Epoch 12/50
#  - 0s - loss: 0.0898
# Epoch 13/50
#  - 0s - loss: 0.0878
# Epoch 14/50
#  - 0s - loss: 0.0851
# Epoch 15/50
#  - 0s - loss: 0.0835
# Epoch 16/50
#  - 0s - loss: 0.0812
# Epoch 17/50
#  - 0s - loss: 0.0802
# Epoch 18/50
#  - 0s - loss: 0.0782
# Epoch 19/50
#  - 0s - loss: 0.0769
# Epoch 20/50
#  - 0s - loss: 0.0757
# Epoch 21/50
#  - 0s - loss: 0.0744
# Epoch 22/50
#  - 0s - loss: 0.0734
# Epoch 23/50
#  - 0s - loss: 0.0720
# Epoch 24/50
#  - 0s - loss: 0.0712
# Epoch 25/50
#  - 0s - loss: 0.0700
# Epoch 26/50
#  - 0s - loss: 0.0691
# Epoch 27/50
#  - 0s - loss: 0.0680
# Epoch 28/50
#  - 0s - loss: 0.0672
# Epoch 29/50
#  - 0s - loss: 0.0661
# Epoch 30/50
#  - 0s - loss: 0.0652
# Epoch 31/50
#  - 0s - loss: 0.0643
# Epoch 32/50
#  - 0s - loss: 0.0635
# Epoch 33/50
#  - 0s - loss: 0.0626
# Epoch 34/50
#  - 0s - loss: 0.0620
# Epoch 35/50
#  - 0s - loss: 0.0610
# Epoch 36/50
#  - 0s - loss: 0.0603
# Epoch 37/50
#  - 0s - loss: 0.0597
# Epoch 38/50
#  - 0s - loss: 0.0592
# Epoch 39/50
#  - 0s - loss: 0.0585
# Epoch 40/50
#  - 0s - loss: 0.0580
# Epoch 41/50
#  - 0s - loss: 0.0575
# Epoch 42/50
#  - 0s - loss: 0.0571
# Epoch 43/50
#  - 0s - loss: 0.0566
# Epoch 44/50
#  - 0s - loss: 0.0563
# Epoch 45/50
#  - 0s - loss: 0.0559
# Epoch 46/50
#  - 0s - loss: 0.0554
# Epoch 47/50
#  - 0s - loss: 0.0546
# Epoch 48/50
#  - 0s - loss: 0.0538
# Epoch 49/50
#  - 0s - loss: 0.0533
# Epoch 50/50
#  - 0s - loss: 0.0535

# %%
#output[2]

# %%
def run_all_models():
    sectors = ['XLB', 'XLE', 'XLF', 'XLI', 'XLK', 'XLU', 'XLV', 'XLY']
    models_l = list()
    for sector in sectors:
        print('Starting model for: ', sector)
        temp_output = lstm_model(sector)
        output_2=temp_output[2]
        models_l.append(output_2)
    return models_l


def sector_rank(models):
    #models is a list of lists
    #for each sector in the list, it is the daily close prices
    #position 0 = the close of last day real data
    #position 250? will be 1 years out forcast
    # position -1 will be 2 years out forcast
    sectors = ['XLB', 'XLE', 'XLF', 'XLI', 'XLK', 'XLU', 'XLV', 'XLY']
    sec_returns_l = list()
    for i in range(len(models)):
        #year 1 return calculation
        y1_temp = models[i]
        sec_returns_l.append(y1_temp)
        
    return sec_returns_l

# %%
returns_list = sector_rank(run_all_models())
# Out:
# Starting model for:  XLB
# Train on 2577 samples, validate on 1000 samples
# Epoch 1/50
#  - 2s - loss: 0.1976 - val_loss: 0.3264
# Epoch 2/50
#  - 0s - loss: 0.1826 - val_loss: 0.3546
# Epoch 3/50
#  - 0s - loss: 0.1708 - val_loss: 0.3743
# Epoch 4/50
#  - 0s - loss: 0.1616 - val_loss: 0.3869
# Epoch 5/50
#  - 0s - loss: 0.1560 - val_loss: 0.3954
# Epoch 6/50
#  - 0s - loss: 0.1525 - val_loss: 0.4020
# Epoch 7/50
#  - 0s - loss: 0.1500 - val_loss: 0.4075
# Epoch 8/50
#  - 0s - loss: 0.1481 - val_loss: 0.4121
# Epoch 9/50
#  - 0s - loss: 0.1464 - val_loss: 0.4158
# Epoch 10/50
#  - 0s - loss: 0.1447 - val_loss: 0.4179
# Epoch 11/50
#  - 0s - loss: 0.1426 - val_loss: 0.4160
# Epoch 12/50
#  - 0s - loss: 0.1393 - val_loss: 0.4001
# Epoch 13/50
#  - 0s - loss: 0.1335 - val_loss: 0.3496
# Epoch 14/50
#  - 0s - loss: 0.1288 - val_loss: 0.3034
# Epoch 15/50
#  - 0s - loss: 0.1240 - val_loss: 0.2843
# Epoch 16/50
#  - 0s - loss: 0.1200 - val_loss: 0.2706
# Epoch 17/50
#  - 0s - loss: 0.1167 - val_loss: 0.2605
# Epoch 18/50
#  - 0s - loss: 0.1143 - val_loss: 0.2512
# Epoch 19/50
#  - 0s - loss: 0.1124 - val_loss: 0.2457
# Epoch 20/50
#  - 0s - loss: 0.1107 - val_loss: 0.2416
# Epoch 21/50
#  - 0s - loss: 0.1093 - val_loss: 0.2382
# Epoch 22/50
#  - 0s - loss: 0.1081 - val_loss: 0.2351
# Epoch 23/50
#  - 0s - loss: 0.1071 - val_loss: 0.2329
# Epoch 24/50
#  - 0s - loss: 0.1061 - val_loss: 0.2311
# Epoch 25/50
#  - 0s - loss: 0.1053 - val_loss: 0.2294
# Epoch 26/50
#  - 0s - loss: 0.1045 - val_loss: 0.2280
# Epoch 27/50
#  - 0s - loss: 0.1038 - val_loss: 0.2266
# Epoch 28/50
#  - 0s - loss: 0.1031 - val_loss: 0.2253
# Epoch 29/50
#  - 0s - loss: 0.1025 - val_loss: 0.2241
# Epoch 30/50
#  - 0s - loss: 0.1019 - val_loss: 0.2233
# Epoch 31/50
#  - 0s - loss: 0.1013 - val_loss: 0.2224
# Epoch 32/50
#  - 0s - loss: 0.1008 - val_loss: 0.2215
# Epoch 33/50
#  - 0s - loss: 0.1003 - val_loss: 0.2206
# Epoch 34/50
#  - 0s - loss: 0.0999 - val_loss: 0.2200
# Epoch 35/50
#  - 0s - loss: 0.0994 - val_loss: 0.2194
# Epoch 36/50
#  - 0s - loss: 0.0990 - val_loss: 0.2188
# Epoch 37/50
#  - 0s - loss: 0.0985 - val_loss: 0.2182
# Epoch 38/50
#  - 0s - loss: 0.0981 - val_loss: 0.2177
# Epoch 39/50
#  - 0s - loss: 0.0976 - val_loss: 0.2170
# Epoch 40/50
#  - 0s - loss: 0.0971 - val_loss: 0.2163
# Epoch 41/50
#  - 0s - loss: 0.0964 - val_loss: 0.2155
# Epoch 42/50
#  - 0s - loss: 0.0955 - val_loss: 0.2138
# Epoch 43/50
#  - 0s - loss: 0.0939 - val_loss: 0.2117
# Epoch 44/50
#  - 0s - loss: 0.0903 - val_loss: 0.2080
# Epoch 45/50
#  - 0s - loss: 0.0829 - val_loss: 0.2040
# Epoch 46/50
#  - 0s - loss: 0.0761 - val_loss: 0.2012
# Epoch 47/50
#  - 0s - loss: 0.0719 - val_loss: 0.1989
# Epoch 48/50
#  - 0s - loss: 0.0664 - val_loss: 0.1966
# Epoch 49/50
#  - 0s - loss: 0.0625 - val_loss: 0.1950
# Epoch 50/50
#  - 0s - loss: 0.0601 - val_loss: 0.1935
# Epoch 1/50
#  - 2s - loss: 0.2346
# Epoch 2/50
#  - 0s - loss: 0.2034
# Epoch 3/50
#  - 0s - loss: 0.1763
# Epoch 4/50
#  - 0s - loss: 0.1447
# Epoch 5/50
#  - 0s - loss: 0.1177
# Epoch 6/50
#  - 0s - loss: 0.1046
# Epoch 7/50
#  - 0s - loss: 0.1001
# Epoch 8/50
#  - 0s - loss: 0.0976
# Epoch 9/50
#  - 0s - loss: 0.0961
# Epoch 10/50
#  - 0s - loss: 0.0948
# Epoch 11/50
#  - 0s - loss: 0.0935
# Epoch 12/50
#  - 0s - loss: 0.0921
# Epoch 13/50
#  - 0s - loss: 0.0907
# Epoch 14/50
#  - 0s - loss: 0.0888
# Epoch 15/50
#  - 0s - loss: 0.0866
# Epoch 16/50
#  - 0s - loss: 0.0838
# Epoch 17/50
#  - 0s - loss: 0.0811
# Epoch 18/50
#  - 0s - loss: 0.0784
# Epoch 19/50
#  - 0s - loss: 0.0749
# Epoch 20/50
#  - 0s - loss: 0.0720
# Epoch 21/50
#  - 0s - loss: 0.0710
# Epoch 22/50
#  - 0s - loss: 0.0694
# Epoch 23/50
#  - 0s - loss: 0.0681
# Epoch 24/50
#  - 0s - loss: 0.0671
# Epoch 25/50
#  - 0s - loss: 0.0747
# Epoch 26/50
#  - 0s - loss: 0.0703
# Epoch 27/50
#  - 0s - loss: 0.0785
# Epoch 28/50
#  - 0s - loss: 0.0709
# Epoch 29/50
#  - 0s - loss: 0.0633
# Epoch 30/50
#  - 0s - loss: 0.0586
# Epoch 31/50
#  - 0s - loss: 0.0652
# Epoch 32/50
#  - 0s - loss: 0.0583
# Epoch 33/50
#  - 0s - loss: 0.0756
# Epoch 34/50
#  - 0s - loss: 0.0624
# Epoch 35/50
#  - 0s - loss: 0.0675
# Epoch 36/50
#  - 0s - loss: 0.0551
# Epoch 37/50
#  - 0s - loss: 0.0532
# Epoch 38/50
#  - 0s - loss: 0.0603
# Epoch 39/50
#  - 0s - loss: 0.0529
# Epoch 40/50
#  - 0s - loss: 0.0608
# Epoch 41/50
#  - 0s - loss: 0.0546
# Epoch 42/50
#  - 0s - loss: 0.0662
# Epoch 43/50
#  - 0s - loss: 0.0511
# Epoch 44/50
#  - 0s - loss: 0.0575
# Epoch 45/50
#  - 0s - loss: 0.0500
# Epoch 46/50
#  - 0s - loss: 0.0681
# Epoch 47/50
#  - 0s - loss: 0.0539
# Epoch 48/50
#  - 0s - loss: 0.0680
# Epoch 49/50
#  - 0s - loss: 0.0470
# Epoch 50/50
#  - 0s - loss: 0.0601
# Starting model for:  XLE
# Train on 2577 samples, validate on 1000 samples
# Epoch 1/50
#  - 2s - loss: 0.2264 - val_loss: 0.2076
# Epoch 2/50
#  - 0s - loss: 0.2091 - val_loss: 0.1901
# Epoch 3/50
#  - 0s - loss: 0.1989 - val_loss: 0.1667
# Epoch 4/50
#  - 0s - loss: 0.1867 - val_loss: 0.1292
# Epoch 5/50
#  - 0s - loss: 0.1727 - val_loss: 0.0887
# Epoch 6/50
#  - 0s - loss: 0.1588 - val_loss: 0.0841
# Epoch 7/50
#  - 0s - loss: 0.1476 - val_loss: 0.0996
# Epoch 8/50
#  - 0s - loss: 0.1386 - val_loss: 0.1108
# Epoch 9/50
#  - 0s - loss: 0.1310 - val_loss: 0.1200
# Epoch 10/50
#  - 0s - loss: 0.1249 - val_loss: 0.1279
# Epoch 11/50
#  - 0s - loss: 0.1199 - val_loss: 0.1341
# Epoch 12/50
#  - 0s - loss: 0.1150 - val_loss: 0.1388
# Epoch 13/50
#  - 0s - loss: 0.1094 - val_loss: 0.1423
# Epoch 14/50
#  - 0s - loss: 0.1034 - val_loss: 0.1452
# Epoch 15/50
#  - 0s - loss: 0.0973 - val_loss: 0.1475
# Epoch 16/50
#  - 0s - loss: 0.0919 - val_loss: 0.1491
# Epoch 17/50
#  - 0s - loss: 0.0868 - val_loss: 0.1506
# Epoch 18/50
#  - 0s - loss: 0.0820 - val_loss: 0.1514
# Epoch 19/50
#  - 0s - loss: 0.0777 - val_loss: 0.1522
# Epoch 20/50
#  - 0s - loss: 0.0742 - val_loss: 0.1515
# Epoch 21/50
#  - 0s - loss: 0.0718 - val_loss: 0.1526
# Epoch 22/50
#  - 0s - loss: 0.0690 - val_loss: 0.1508
# Epoch 23/50
#  - 0s - loss: 0.0666 - val_loss: 0.1490
# Epoch 24/50
#  - 0s - loss: 0.0648 - val_loss: 0.1484
# Epoch 25/50
#  - 0s - loss: 0.0624 - val_loss: 0.1450
# Epoch 26/50
#  - 0s - loss: 0.0603 - val_loss: 0.1406
# Epoch 27/50
#  - 0s - loss: 0.0586 - val_loss: 0.1338
# Epoch 28/50
#  - 0s - loss: 0.0574 - val_loss: 0.1330
# Epoch 29/50
#  - 0s - loss: 0.0564 - val_loss: 0.1304
# Epoch 30/50
#  - 0s - loss: 0.0553 - val_loss: 0.1236
# Epoch 31/50
#  - 0s - loss: 0.0533 - val_loss: 0.1113
# Epoch 32/50
#  - 0s - loss: 0.0527 - val_loss: 0.1019
# Epoch 33/50
#  - 0s - loss: 0.0524 - val_loss: 0.1134
# Epoch 34/50
#  - 0s - loss: 0.0531 - val_loss: 0.1169
# Epoch 35/50
#  - 0s - loss: 0.0525 - val_loss: 0.0997
# Epoch 36/50
#  - 0s - loss: 0.0484 - val_loss: 0.0727
# Epoch 37/50
#  - 0s - loss: 0.0510 - val_loss: 0.0784
# Epoch 38/50
#  - 0s - loss: 0.0496 - val_loss: 0.1110
# Epoch 39/50
#  - 0s - loss: 0.0548 - val_loss: 0.0984
# Epoch 40/50
#  - 0s - loss: 0.0463 - val_loss: 0.0540
# Epoch 41/50
#  - 0s - loss: 0.0570 - val_loss: 0.0916
# Epoch 42/50
#  - 0s - loss: 0.0503 - val_loss: 0.1080
# Epoch 43/50
#  - 0s - loss: 0.0509 - val_loss: 0.0651
# Epoch 44/50
#  - 0s - loss: 0.0472 - val_loss: 0.0568
# Epoch 45/50
#  - 0s - loss: 0.0541 - val_loss: 0.0883
# Epoch 46/50
#  - 0s - loss: 0.0512 - val_loss: 0.1108
# Epoch 47/50
#  - 0s - loss: 0.0496 - val_loss: 0.0543
# Epoch 48/50
#  - 0s - loss: 0.0525 - val_loss: 0.0530
# Epoch 49/50
#  - 0s - loss: 0.0485 - val_loss: 0.1074
# Epoch 50/50
#  - 0s - loss: 0.0567 - val_loss: 0.1022
# Epoch 1/50
#  - 2s - loss: 0.1983
# Epoch 2/50
#  - 0s - loss: 0.1954
# Epoch 3/50
#  - 0s - loss: 0.1911
# Epoch 4/50
#  - 0s - loss: 0.1831
# Epoch 5/50
#  - 0s - loss: 0.1719
# Epoch 6/50
#  - 0s - loss: 0.1614
# Epoch 7/50
#  - 0s - loss: 0.1533
# Epoch 8/50
#  - 0s - loss: 0.1474
# Epoch 9/50
#  - 0s - loss: 0.1434
# Epoch 10/50
#  - 0s - loss: 0.1408
# Epoch 11/50
#  - 0s - loss: 0.1390
# Epoch 12/50
#  - 0s - loss: 0.1375
# Epoch 13/50
#  - 0s - loss: 0.1364
# Epoch 14/50
#  - 0s - loss: 0.1355
# Epoch 15/50
#  - 0s - loss: 0.1348
# Epoch 16/50
#  - 0s - loss: 0.1341
# Epoch 17/50
#  - 0s - loss: 0.1335
# Epoch 18/50
#  - 0s - loss: 0.1330
# Epoch 19/50
#  - 0s - loss: 0.1325
# Epoch 20/50
#  - 0s - loss: 0.1320
# Epoch 21/50
#  - 0s - loss: 0.1316
# Epoch 22/50
#  - 0s - loss: 0.1312
# Epoch 23/50
#  - 0s - loss: 0.1309
# Epoch 24/50
#  - 0s - loss: 0.1305
# Epoch 25/50
#  - 0s - loss: 0.1301
# Epoch 26/50
#  - 0s - loss: 0.1295
# Epoch 27/50
#  - 0s - loss: 0.1267
# Epoch 28/50
#  - 0s - loss: 0.1314
# Epoch 29/50
#  - 0s - loss: 0.1312
# Epoch 30/50
#  - 0s - loss: 0.1320
# Epoch 31/50
#  - 0s - loss: 0.1308
# Epoch 32/50
#  - 0s - loss: 0.1333
# Epoch 33/50
#  - 0s - loss: 0.1297
# Epoch 34/50
#  - 0s - loss: 0.1249
# Epoch 35/50
#  - 0s - loss: 0.1321
# Epoch 36/50
#  - 0s - loss: 0.1268
# Epoch 37/50
#  - 0s - loss: 0.1248
# Epoch 38/50
#  - 0s - loss: 0.1263
# Epoch 39/50
#  - 0s - loss: 0.1250
# Epoch 40/50
#  - 0s - loss: 0.1260
# Epoch 41/50
#  - 0s - loss: 0.1238
# Epoch 42/50
#  - 0s - loss: 0.1248
# Epoch 43/50
#  - 0s - loss: 0.1233
# Epoch 44/50
#  - 0s - loss: 0.1225
# Epoch 45/50
#  - 0s - loss: 0.1216
# Epoch 46/50
#  - 0s - loss: 0.1211
# Epoch 47/50
#  - 0s - loss: 0.1201
# Epoch 48/50
#  - 0s - loss: 0.1193
# Epoch 49/50
#  - 0s - loss: 0.1181
# Epoch 50/50
#  - 0s - loss: 0.1173
# Starting model for:  XLF
# Train on 2577 samples, validate on 1000 samples
# Epoch 1/50
#  - 2s - loss: 0.2444 - val_loss: 0.1336
# Epoch 2/50
#  - 0s - loss: 0.2157 - val_loss: 0.1526
# Epoch 3/50
#  - 0s - loss: 0.1959 - val_loss: 0.2229
# Epoch 4/50
#  - 0s - loss: 0.1783 - val_loss: 0.2868
# Epoch 5/50
#  - 0s - loss: 0.1643 - val_loss: 0.3273
# Epoch 6/50
#  - 0s - loss: 0.1511 - val_loss: 0.3607
# Epoch 7/50
#  - 0s - loss: 0.1392 - val_loss: 0.3867
# Epoch 8/50
#  - 0s - loss: 0.1292 - val_loss: 0.3997
# Epoch 9/50
#  - 0s - loss: 0.1201 - val_loss: 0.3993
# Epoch 10/50
#  - 0s - loss: 0.1111 - val_loss: 0.3913
# Epoch 11/50
#  - 0s - loss: 0.1042 - val_loss: 0.3753
# Epoch 12/50
#  - 0s - loss: 0.0983 - val_loss: 0.3430
# Epoch 13/50
#  - 0s - loss: 0.0924 - val_loss: 0.2917
# Epoch 14/50
#  - 0s - loss: 0.0858 - val_loss: 0.2202
# Epoch 15/50
#  - 0s - loss: 0.0779 - val_loss: 0.1445
# Epoch 16/50
#  - 0s - loss: 0.0685 - val_loss: 0.0815
# Epoch 17/50
#  - 0s - loss: 0.0587 - val_loss: 0.0677
# Epoch 18/50
#  - 0s - loss: 0.0565 - val_loss: 0.0704
# Epoch 19/50
#  - 0s - loss: 0.0534 - val_loss: 0.0766
# Epoch 20/50
#  - 0s - loss: 0.0468 - val_loss: 0.1002
# Epoch 21/50
#  - 0s - loss: 0.0430 - val_loss: 0.1129
# Epoch 22/50
#  - 0s - loss: 0.0417 - val_loss: 0.1191
# Epoch 23/50
#  - 0s - loss: 0.0458 - val_loss: 0.1332
# Epoch 24/50
#  - 0s - loss: 0.0408 - val_loss: 0.1306
# Epoch 25/50
#  - 0s - loss: 0.0412 - val_loss: 0.1346
# Epoch 26/50
#  - 0s - loss: 0.0442 - val_loss: 0.1307
# Epoch 27/50
#  - 0s - loss: 0.0430 - val_loss: 0.1342
# Epoch 28/50
#  - 0s - loss: 0.0399 - val_loss: 0.1302
# Epoch 29/50
#  - 0s - loss: 0.0412 - val_loss: 0.1321
# Epoch 30/50
#  - 0s - loss: 0.0404 - val_loss: 0.1281
# Epoch 31/50
#  - 0s - loss: 0.0394 - val_loss: 0.1271
# Epoch 32/50
#  - 0s - loss: 0.0390 - val_loss: 0.1261
# Epoch 33/50
#  - 0s - loss: 0.0394 - val_loss: 0.1240
# Epoch 34/50
#  - 0s - loss: 0.0385 - val_loss: 0.1227
# Epoch 35/50
#  - 0s - loss: 0.0377 - val_loss: 0.1197
# Epoch 36/50
#  - 0s - loss: 0.0367 - val_loss: 0.1236
# Epoch 37/50
#  - 0s - loss: 0.0378 - val_loss: 0.1176
# Epoch 38/50
#  - 0s - loss: 0.0378 - val_loss: 0.1187
# Epoch 39/50
#  - 0s - loss: 0.0364 - val_loss: 0.1132
# Epoch 40/50
#  - 0s - loss: 0.0354 - val_loss: 0.1186
# Epoch 41/50
#  - 0s - loss: 0.0361 - val_loss: 0.1111
# Epoch 42/50
#  - 0s - loss: 0.0358 - val_loss: 0.1153
# Epoch 43/50
#  - 0s - loss: 0.0351 - val_loss: 0.1072
# Epoch 44/50
#  - 0s - loss: 0.0346 - val_loss: 0.1141
# Epoch 45/50
#  - 0s - loss: 0.0348 - val_loss: 0.1039
# Epoch 46/50
#  - 0s - loss: 0.0349 - val_loss: 0.1106
# Epoch 47/50
#  - 0s - loss: 0.0342 - val_loss: 0.1002
# Epoch 48/50
#  - 0s - loss: 0.0333 - val_loss: 0.1073
# Epoch 49/50
#  - 0s - loss: 0.0324 - val_loss: 0.0990
# Epoch 50/50
#  - 0s - loss: 0.0325 - val_loss: 0.1044
# Epoch 1/50
#  - 2s - loss: 0.2094
# Epoch 2/50
#  - 0s - loss: 0.2064
# Epoch 3/50
#  - 0s - loss: 0.2037
# Epoch 4/50
#  - 0s - loss: 0.2006
# Epoch 5/50
#  - 0s - loss: 0.1959
# Epoch 6/50
#  - 0s - loss: 0.1882
# Epoch 7/50
#  - 0s - loss: 0.1780
# Epoch 8/50
#  - 0s - loss: 0.1680
# Epoch 9/50
#  - 0s - loss: 0.1601
# Epoch 10/50
#  - 0s - loss: 0.1537
# Epoch 11/50
#  - 0s - loss: 0.1481
# Epoch 12/50
#  - 0s - loss: 0.1432
# Epoch 13/50
#  - 0s - loss: 0.1388
# Epoch 14/50
#  - 0s - loss: 0.1359
# Epoch 15/50
#  - 0s - loss: 0.1320
# Epoch 16/50
#  - 0s - loss: 0.1299
# Epoch 17/50
#  - 0s - loss: 0.1236
# Epoch 18/50
#  - 0s - loss: 0.1213
# Epoch 19/50
#  - 0s - loss: 0.1189
# Epoch 20/50
#  - 0s - loss: 0.1159
# Epoch 21/50
#  - 0s - loss: 0.1151
# Epoch 22/50
#  - 0s - loss: 0.1122
# Epoch 23/50
#  - 0s - loss: 0.1084
# Epoch 24/50
#  - 0s - loss: 0.1093
# Epoch 25/50
#  - 0s - loss: 0.1058
# Epoch 26/50
#  - 0s - loss: 0.1018
# Epoch 27/50
#  - 0s - loss: 0.0999
# Epoch 28/50
#  - 0s - loss: 0.0957
# Epoch 29/50
#  - 0s - loss: 0.0909
# Epoch 30/50
#  - 0s - loss: 0.0881
# Epoch 31/50
#  - 0s - loss: 0.0924
# Epoch 32/50
#  - 0s - loss: 0.0822
# Epoch 33/50
#  - 0s - loss: 0.0815
# Epoch 34/50
#  - 0s - loss: 0.0860
# Epoch 35/50
#  - 0s - loss: 0.0730
# Epoch 36/50
#  - 0s - loss: 0.0746
# Epoch 37/50
#  - 0s - loss: 0.0827
# Epoch 38/50
#  - 0s - loss: 0.0693
# Epoch 39/50
#  - 0s - loss: 0.0699
# Epoch 40/50
#  - 0s - loss: 0.0807
# Epoch 41/50
#  - 0s - loss: 0.0670
# Epoch 42/50
#  - 0s - loss: 0.0707
# Epoch 43/50
#  - 0s - loss: 0.0801
# Epoch 44/50
#  - 0s - loss: 0.0645
# Epoch 45/50
#  - 0s - loss: 0.0710
# Epoch 46/50
#  - 0s - loss: 0.0767
# Epoch 47/50
#  - 0s - loss: 0.0611
# Epoch 48/50
#  - 0s - loss: 0.0693
# Epoch 49/50
#  - 0s - loss: 0.0728
# Epoch 50/50
#  - 0s - loss: 0.0562
# Starting model for:  XLI
# Train on 2577 samples, validate on 1000 samples
# Epoch 1/50
#  - 2s - loss: 0.2353 - val_loss: 0.4156
# Epoch 2/50
#  - 0s - loss: 0.1208 - val_loss: 0.4941
# Epoch 3/50
#  - 0s - loss: 0.0957 - val_loss: 0.5070
# Epoch 4/50
#  - 0s - loss: 0.0877 - val_loss: 0.5080
# Epoch 5/50
#  - 0s - loss: 0.0836 - val_loss: 0.5019
# Epoch 6/50
#  - 0s - loss: 0.0807 - val_loss: 0.4912
# Epoch 7/50
#  - 0s - loss: 0.0779 - val_loss: 0.4752
# Epoch 8/50
#  - 0s - loss: 0.0754 - val_loss: 0.4568
# Epoch 9/50
#  - 0s - loss: 0.0731 - val_loss: 0.4383
# Epoch 10/50
#  - 0s - loss: 0.0708 - val_loss: 0.4178
# Epoch 11/50
#  - 0s - loss: 0.0687 - val_loss: 0.3952
# Epoch 12/50
#  - 0s - loss: 0.0665 - val_loss: 0.3698
# Epoch 13/50
#  - 0s - loss: 0.0647 - val_loss: 0.3445
# Epoch 14/50
#  - 0s - loss: 0.0629 - val_loss: 0.3156
# Epoch 15/50
#  - 0s - loss: 0.0617 - val_loss: 0.2855
# Epoch 16/50
#  - 0s - loss: 0.0604 - val_loss: 0.2527
# Epoch 17/50
#  - 0s - loss: 0.0593 - val_loss: 0.2202
# Epoch 18/50
#  - 0s - loss: 0.0577 - val_loss: 0.1849
# Epoch 19/50
#  - 0s - loss: 0.0561 - val_loss: 0.1470
# Epoch 20/50
#  - 0s - loss: 0.0542 - val_loss: 0.1097
# Epoch 21/50
#  - 0s - loss: 0.0516 - val_loss: 0.0781
# Epoch 22/50
#  - 0s - loss: 0.0486 - val_loss: 0.0636
# Epoch 23/50
#  - 0s - loss: 0.0447 - val_loss: 0.0666
# Epoch 24/50
#  - 0s - loss: 0.0418 - val_loss: 0.0754
# Epoch 25/50
#  - 0s - loss: 0.0402 - val_loss: 0.0835
# Epoch 26/50
#  - 0s - loss: 0.0396 - val_loss: 0.0877
# Epoch 27/50
#  - 0s - loss: 0.0379 - val_loss: 0.0828
# Epoch 28/50
#  - 0s - loss: 0.0370 - val_loss: 0.0853
# Epoch 29/50
#  - 0s - loss: 0.0373 - val_loss: 0.0911
# Epoch 30/50
#  - 0s - loss: 0.0360 - val_loss: 0.0872
# Epoch 31/50
#  - 0s - loss: 0.0353 - val_loss: 0.0830
# Epoch 32/50
#  - 0s - loss: 0.0346 - val_loss: 0.0860
# Epoch 33/50
#  - 0s - loss: 0.0356 - val_loss: 0.0871
# Epoch 34/50
#  - 0s - loss: 0.0343 - val_loss: 0.0836
# Epoch 35/50
#  - 0s - loss: 0.0342 - val_loss: 0.0786
# Epoch 36/50
#  - 0s - loss: 0.0367 - val_loss: 0.0719
# Epoch 37/50
#  - 0s - loss: 0.0381 - val_loss: 0.0903
# Epoch 38/50
#  - 0s - loss: 0.0364 - val_loss: 0.0874
# Epoch 39/50
#  - 0s - loss: 0.0379 - val_loss: 0.0783
# Epoch 40/50
#  - 0s - loss: 0.0550 - val_loss: 0.0768
# Epoch 41/50
#  - 0s - loss: 0.0621 - val_loss: 0.0596
# Epoch 42/50
#  - 0s - loss: 0.0340 - val_loss: 0.0665
# Epoch 43/50
#  - 0s - loss: 0.0353 - val_loss: 0.0725
# Epoch 44/50
#  - 0s - loss: 0.0359 - val_loss: 0.0867
# Epoch 45/50
#  - 0s - loss: 0.0355 - val_loss: 0.0790
# Epoch 46/50
#  - 0s - loss: 0.0318 - val_loss: 0.0732
# Epoch 47/50
#  - 0s - loss: 0.0418 - val_loss: 0.0741
# Epoch 48/50
#  - 0s - loss: 0.0347 - val_loss: 0.0779
# Epoch 49/50
#  - 0s - loss: 0.0343 - val_loss: 0.0724
# Epoch 50/50
#  - 0s - loss: 0.0325 - val_loss: 0.0674
# Epoch 1/50
#  - 2s - loss: 0.2686
# Epoch 2/50
#  - 0s - loss: 0.2449
# Epoch 3/50
#  - 0s - loss: 0.2289
# Epoch 4/50
#  - 0s - loss: 0.2176
# Epoch 5/50
#  - 0s - loss: 0.2102
# Epoch 6/50
#  - 0s - loss: 0.2031
# Epoch 7/50
#  - 0s - loss: 0.1794
# Epoch 8/50
#  - 0s - loss: 0.1388
# Epoch 9/50
#  - 0s - loss: 0.1216
# Epoch 10/50
#  - 0s - loss: 0.1081
# Epoch 11/50
#  - 0s - loss: 0.0997
# Epoch 12/50
#  - 0s - loss: 0.0940
# Epoch 13/50
#  - 0s - loss: 0.0900
# Epoch 14/50
#  - 0s - loss: 0.0869
# Epoch 15/50
#  - 0s - loss: 0.0844
# Epoch 16/50
#  - 0s - loss: 0.0822
# Epoch 17/50
#  - 0s - loss: 0.0803
# Epoch 18/50
#  - 0s - loss: 0.0786
# Epoch 19/50
#  - 0s - loss: 0.0772
# Epoch 20/50
#  - 0s - loss: 0.0759
# Epoch 21/50
#  - 0s - loss: 0.0748
# Epoch 22/50
#  - 0s - loss: 0.0739
# Epoch 23/50
#  - 0s - loss: 0.0731
# Epoch 24/50
#  - 0s - loss: 0.0723
# Epoch 25/50
#  - 0s - loss: 0.0716
# Epoch 26/50
#  - 0s - loss: 0.0710
# Epoch 27/50
#  - 0s - loss: 0.0704
# Epoch 28/50
#  - 0s - loss: 0.0698
# Epoch 29/50
#  - 0s - loss: 0.0693
# Epoch 30/50
#  - 0s - loss: 0.0688
# Epoch 31/50
#  - 0s - loss: 0.0684
# Epoch 32/50
#  - 0s - loss: 0.0680
# Epoch 33/50
#  - 0s - loss: 0.0676
# Epoch 34/50
#  - 0s - loss: 0.0674
# Epoch 35/50
#  - 0s - loss: 0.0669
# Epoch 36/50
#  - 0s - loss: 0.0666
# Epoch 37/50
#  - 0s - loss: 0.0661
# Epoch 38/50
#  - 0s - loss: 0.0657
# Epoch 39/50
#  - 0s - loss: 0.0652
# Epoch 40/50
#  - 0s - loss: 0.0645
# Epoch 41/50
#  - 0s - loss: 0.0637
# Epoch 42/50
#  - 0s - loss: 0.0622
# Epoch 43/50
#  - 0s - loss: 0.0597
# Epoch 44/50
#  - 0s - loss: 0.0588
# Epoch 45/50
#  - 0s - loss: 0.0573
# Epoch 46/50
#  - 0s - loss: 0.0551
# Epoch 47/50
#  - 0s - loss: 0.0539
# Epoch 48/50
#  - 0s - loss: 0.0523
# Epoch 49/50
#  - 0s - loss: 0.0518
# Epoch 50/50
#  - 0s - loss: 0.0510
# Starting model for:  XLK
# Train on 2577 samples, validate on 1000 samples
# Epoch 1/50
#  - 2s - loss: 0.3189 - val_loss: 0.1532
# Epoch 2/50
#  - 0s - loss: 0.2755 - val_loss: 0.1739
# Epoch 3/50
#  - 0s - loss: 0.2358 - val_loss: 0.1942
# Epoch 4/50
#  - 0s - loss: 0.2111 - val_loss: 0.2113
# Epoch 5/50
#  - 0s - loss: 0.1937 - val_loss: 0.2274
# Epoch 6/50
#  - 0s - loss: 0.1797 - val_loss: 0.2422
# Epoch 7/50
#  - 0s - loss: 0.1676 - val_loss: 0.2556
# Epoch 8/50
#  - 0s - loss: 0.1569 - val_loss: 0.2680
# Epoch 9/50
#  - 0s - loss: 0.1472 - val_loss: 0.2796
# Epoch 10/50
#  - 0s - loss: 0.1383 - val_loss: 0.2906
# Epoch 11/50
#  - 0s - loss: 0.1305 - val_loss: 0.3006
# Epoch 12/50
#  - 0s - loss: 0.1236 - val_loss: 0.3098
# Epoch 13/50
#  - 0s - loss: 0.1174 - val_loss: 0.3183
# Epoch 14/50
#  - 0s - loss: 0.1120 - val_loss: 0.3262
# Epoch 15/50
#  - 0s - loss: 0.1071 - val_loss: 0.3336
# Epoch 16/50
#  - 0s - loss: 0.1029 - val_loss: 0.3403
# Epoch 17/50
#  - 0s - loss: 0.0993 - val_loss: 0.3464
# Epoch 18/50
#  - 0s - loss: 0.0960 - val_loss: 0.3521
# Epoch 19/50
#  - 0s - loss: 0.0931 - val_loss: 0.3575
# Epoch 20/50
#  - 0s - loss: 0.0904 - val_loss: 0.3625
# Epoch 21/50
#  - 0s - loss: 0.0880 - val_loss: 0.3670
# Epoch 22/50
#  - 0s - loss: 0.0860 - val_loss: 0.3711
# Epoch 23/50
#  - 0s - loss: 0.0845 - val_loss: 0.3748
# Epoch 24/50
#  - 0s - loss: 0.0832 - val_loss: 0.3781
# Epoch 25/50
#  - 0s - loss: 0.0821 - val_loss: 0.3811
# Epoch 26/50
#  - 0s - loss: 0.0811 - val_loss: 0.3839
# Epoch 27/50
#  - 0s - loss: 0.0803 - val_loss: 0.3865
# Epoch 28/50
#  - 0s - loss: 0.0796 - val_loss: 0.3888
# Epoch 29/50
#  - 0s - loss: 0.0789 - val_loss: 0.3911
# Epoch 30/50
#  - 0s - loss: 0.0784 - val_loss: 0.3931
# Epoch 31/50
#  - 0s - loss: 0.0779 - val_loss: 0.3950
# Epoch 32/50
#  - 0s - loss: 0.0775 - val_loss: 0.3967
# Epoch 33/50
#  - 0s - loss: 0.0772 - val_loss: 0.3983
# Epoch 34/50
#  - 0s - loss: 0.0768 - val_loss: 0.3999
# Epoch 35/50
#  - 0s - loss: 0.0766 - val_loss: 0.4013
# Epoch 36/50
#  - 0s - loss: 0.0763 - val_loss: 0.4027
# Epoch 37/50
#  - 0s - loss: 0.0761 - val_loss: 0.4040
# Epoch 38/50
#  - 0s - loss: 0.0759 - val_loss: 0.4051
# Epoch 39/50
#  - 0s - loss: 0.0757 - val_loss: 0.4062
# Epoch 40/50
#  - 0s - loss: 0.0756 - val_loss: 0.4071
# Epoch 41/50
#  - 0s - loss: 0.0754 - val_loss: 0.4081
# Epoch 42/50
#  - 0s - loss: 0.0753 - val_loss: 0.4089
# Epoch 43/50
#  - 0s - loss: 0.0752 - val_loss: 0.4097
# Epoch 44/50
#  - 0s - loss: 0.0751 - val_loss: 0.4105
# Epoch 45/50
#  - 0s - loss: 0.0751 - val_loss: 0.4112
# Epoch 46/50
#  - 0s - loss: 0.0750 - val_loss: 0.4118
# Epoch 47/50
#  - 0s - loss: 0.0750 - val_loss: 0.4125
# Epoch 48/50
#  - 0s - loss: 0.0749 - val_loss: 0.4131
# Epoch 49/50
#  - 0s - loss: 0.0748 - val_loss: 0.4136
# Epoch 50/50
#  - 0s - loss: 0.0748 - val_loss: 0.4141
# Epoch 1/50
#  - 2s - loss: 0.2728
# Epoch 2/50
#  - 0s - loss: 0.2520
# Epoch 3/50
#  - 0s - loss: 0.2366
# Epoch 4/50
#  - 0s - loss: 0.2274
# Epoch 5/50
#  - 0s - loss: 0.2211
# Epoch 6/50
#  - 0s - loss: 0.2160
# Epoch 7/50
#  - 0s - loss: 0.2119
# Epoch 8/50
#  - 0s - loss: 0.2084
# Epoch 9/50
#  - 0s - loss: 0.2052
# Epoch 10/50
#  - 0s - loss: 0.2023
# Epoch 11/50
#  - 0s - loss: 0.1996
# Epoch 12/50
#  - 0s - loss: 0.1971
# Epoch 13/50
#  - 0s - loss: 0.1948
# Epoch 14/50
#  - 0s - loss: 0.1926
# Epoch 15/50
#  - 0s - loss: 0.1905
# Epoch 16/50
#  - 0s - loss: 0.1886
# Epoch 17/50
#  - 0s - loss: 0.1867
# Epoch 18/50
#  - 0s - loss: 0.1850
# Epoch 19/50
#  - 0s - loss: 0.1834
# Epoch 20/50
#  - 0s - loss: 0.1818
# Epoch 21/50
#  - 0s - loss: 0.1803
# Epoch 22/50
#  - 0s - loss: 0.1790
# Epoch 23/50
#  - 0s - loss: 0.1778
# Epoch 24/50
#  - 0s - loss: 0.1767
# Epoch 25/50
#  - 0s - loss: 0.1757
# Epoch 26/50
#  - 0s - loss: 0.1748
# Epoch 27/50
#  - 0s - loss: 0.1739
# Epoch 28/50
#  - 0s - loss: 0.1731
# Epoch 29/50
#  - 0s - loss: 0.1724
# Epoch 30/50
#  - 0s - loss: 0.1717
# Epoch 31/50
#  - 0s - loss: 0.1711
# Epoch 32/50
#  - 0s - loss: 0.1705
# Epoch 33/50
#  - 0s - loss: 0.1700
# Epoch 34/50
#  - 0s - loss: 0.1696
# Epoch 35/50
#  - 0s - loss: 0.1692
# Epoch 36/50
#  - 0s - loss: 0.1689
# Epoch 37/50
#  - 0s - loss: 0.1686
# Epoch 38/50
#  - 0s - loss: 0.1683
# Epoch 39/50
#  - 0s - loss: 0.1680
# Epoch 40/50
#  - 0s - loss: 0.1678
# Epoch 41/50
#  - 0s - loss: 0.1676
# Epoch 42/50
#  - 0s - loss: 0.1674
# Epoch 43/50
#  - 0s - loss: 0.1672
# Epoch 44/50
#  - 0s - loss: 0.1671
# Epoch 45/50
#  - 0s - loss: 0.1669
# Epoch 46/50
#  - 0s - loss: 0.1667
# Epoch 47/50
#  - 0s - loss: 0.1666
# Epoch 48/50
#  - 0s - loss: 0.1665
# Epoch 49/50
#  - 0s - loss: 0.1663
# Epoch 50/50
#  - 0s - loss: 0.1662
# Starting model for:  XLU
# Train on 2577 samples, validate on 1000 samples
# Epoch 1/50
#  - 2s - loss: 0.1519 - val_loss: 0.3352
# Epoch 2/50
#  - 0s - loss: 0.1180 - val_loss: 0.3722
# Epoch 3/50
#  - 0s - loss: 0.1043 - val_loss: 0.3848
# Epoch 4/50
#  - 0s - loss: 0.0979 - val_loss: 0.3886
# Epoch 5/50
#  - 0s - loss: 0.0947 - val_loss: 0.3874
# Epoch 6/50
#  - 0s - loss: 0.0926 - val_loss: 0.3828
# Epoch 7/50
#  - 0s - loss: 0.0908 - val_loss: 0.3747
# Epoch 8/50
#  - 0s - loss: 0.0889 - val_loss: 0.3606
# Epoch 9/50
#  - 0s - loss: 0.0866 - val_loss: 0.3371
# Epoch 10/50
#  - 0s - loss: 0.0845 - val_loss: 0.3074
# Epoch 11/50
#  - 0s - loss: 0.0827 - val_loss: 0.2771
# Epoch 12/50
#  - 0s - loss: 0.0805 - val_loss: 0.2453
# Epoch 13/50
#  - 0s - loss: 0.0785 - val_loss: 0.2162
# Epoch 14/50
#  - 0s - loss: 0.0762 - val_loss: 0.1884
# Epoch 15/50
#  - 0s - loss: 0.0742 - val_loss: 0.1603
# Epoch 16/50
#  - 0s - loss: 0.0718 - val_loss: 0.1341
# Epoch 17/50
#  - 0s - loss: 0.0696 - val_loss: 0.1153
# Epoch 18/50
#  - 0s - loss: 0.0668 - val_loss: 0.1037
# Epoch 19/50
#  - 0s - loss: 0.0634 - val_loss: 0.0968
# Epoch 20/50
#  - 0s - loss: 0.0594 - val_loss: 0.0931
# Epoch 21/50
#  - 0s - loss: 0.0559 - val_loss: 0.0919
# Epoch 22/50
#  - 0s - loss: 0.0540 - val_loss: 0.0918
# Epoch 23/50
#  - 0s - loss: 0.0534 - val_loss: 0.0918
# Epoch 24/50
#  - 0s - loss: 0.0515 - val_loss: 0.0911
# Epoch 25/50
#  - 0s - loss: 0.0498 - val_loss: 0.0907
# Epoch 26/50
#  - 0s - loss: 0.0492 - val_loss: 0.0908
# Epoch 27/50
#  - 0s - loss: 0.0504 - val_loss: 0.0908
# Epoch 28/50
#  - 0s - loss: 0.0474 - val_loss: 0.0900
# Epoch 29/50
#  - 0s - loss: 0.0484 - val_loss: 0.0895
# Epoch 30/50
#  - 0s - loss: 0.0468 - val_loss: 0.0900
# Epoch 31/50
#  - 0s - loss: 0.0508 - val_loss: 0.0897
# Epoch 32/50
#  - 0s - loss: 0.0460 - val_loss: 0.0892
# Epoch 33/50
#  - 0s - loss: 0.0495 - val_loss: 0.0884
# Epoch 34/50
#  - 0s - loss: 0.0461 - val_loss: 0.0891
# Epoch 35/50
#  - 0s - loss: 0.0523 - val_loss: 0.0890
# Epoch 36/50
#  - 0s - loss: 0.0454 - val_loss: 0.0883
# Epoch 37/50
#  - 0s - loss: 0.0508 - val_loss: 0.0878
# Epoch 38/50
#  - 0s - loss: 0.0442 - val_loss: 0.0883
# Epoch 39/50
#  - 0s - loss: 0.0496 - val_loss: 0.0886
# Epoch 40/50
#  - 0s - loss: 0.0439 - val_loss: 0.0883
# Epoch 41/50
#  - 0s - loss: 0.0505 - val_loss: 0.0872
# Epoch 42/50
#  - 0s - loss: 0.0442 - val_loss: 0.0877
# Epoch 43/50
#  - 0s - loss: 0.0511 - val_loss: 0.0896
# Epoch 44/50
#  - 0s - loss: 0.0420 - val_loss: 0.0882
# Epoch 45/50
#  - 0s - loss: 0.0470 - val_loss: 0.0867
# Epoch 46/50
#  - 0s - loss: 0.0417 - val_loss: 0.0870
# Epoch 47/50
#  - 0s - loss: 0.0483 - val_loss: 0.0887
# Epoch 48/50
#  - 0s - loss: 0.0419 - val_loss: 0.0883
# Epoch 49/50
#  - 0s - loss: 0.0478 - val_loss: 0.0864
# Epoch 50/50
#  - 0s - loss: 0.0399 - val_loss: 0.0865
# Epoch 1/50
#  - 2s - loss: 0.1971
# Epoch 2/50
#  - 0s - loss: 0.1853
# Epoch 3/50
#  - 0s - loss: 0.1784
# Epoch 4/50
#  - 0s - loss: 0.1723
# Epoch 5/50
#  - 0s - loss: 0.1615
# Epoch 6/50
#  - 0s - loss: 0.1428
# Epoch 7/50
#  - 0s - loss: 0.1281
# Epoch 8/50
#  - 0s - loss: 0.1129
# Epoch 9/50
#  - 0s - loss: 0.1040
# Epoch 10/50
#  - 0s - loss: 0.0981
# Epoch 11/50
#  - 0s - loss: 0.0935
# Epoch 12/50
#  - 0s - loss: 0.0905
# Epoch 13/50
#  - 0s - loss: 0.0884
# Epoch 14/50
#  - 0s - loss: 0.0870
# Epoch 15/50
#  - 0s - loss: 0.0856
# Epoch 16/50
#  - 0s - loss: 0.0849
# Epoch 17/50
#  - 0s - loss: 0.0836
# Epoch 18/50
#  - 0s - loss: 0.0837
# Epoch 19/50
#  - 0s - loss: 0.0822
# Epoch 20/50
#  - 0s - loss: 0.0824
# Epoch 21/50
#  - 0s - loss: 0.0806
# Epoch 22/50
#  - 0s - loss: 0.0814
# Epoch 23/50
#  - 0s - loss: 0.0793
# Epoch 24/50
#  - 0s - loss: 0.0802
# Epoch 25/50
#  - 0s - loss: 0.0781
# Epoch 26/50
#  - 0s - loss: 0.0789
# Epoch 27/50
#  - 0s - loss: 0.0769
# Epoch 28/50
#  - 0s - loss: 0.0772
# Epoch 29/50
#  - 0s - loss: 0.0762
# Epoch 30/50
#  - 0s - loss: 0.0755
# Epoch 31/50
#  - 0s - loss: 0.0752
# Epoch 32/50
#  - 0s - loss: 0.0746
# Epoch 33/50
#  - 0s - loss: 0.0740
# Epoch 34/50
#  - 0s - loss: 0.0735
# Epoch 35/50
#  - 0s - loss: 0.0733
# Epoch 36/50
#  - 0s - loss: 0.0727
# Epoch 37/50
#  - 0s - loss: 0.0722
# Epoch 38/50
#  - 0s - loss: 0.0717
# Epoch 39/50
#  - 0s - loss: 0.0714
# Epoch 40/50
#  - 0s - loss: 0.0710
# Epoch 41/50
#  - 0s - loss: 0.0707
# Epoch 42/50
#  - 0s - loss: 0.0703
# Epoch 43/50
#  - 0s - loss: 0.0700
# Epoch 44/50
#  - 0s - loss: 0.0696
# Epoch 45/50
#  - 0s - loss: 0.0692
# Epoch 46/50
#  - 0s - loss: 0.0689
# Epoch 47/50
#  - 0s - loss: 0.0686
# Epoch 48/50
#  - 0s - loss: 0.0683
# Epoch 49/50
#  - 0s - loss: 0.0680
# Epoch 50/50
#  - 0s - loss: 0.0673
# Starting model for:  XLV
# Train on 2577 samples, validate on 1000 samples
# Epoch 1/50
#  - 3s - loss: 0.3242 - val_loss: 0.3396
# Epoch 2/50
#  - 0s - loss: 0.2617 - val_loss: 0.3900
# Epoch 3/50
#  - 0s - loss: 0.2210 - val_loss: 0.4110
# Epoch 4/50
#  - 0s - loss: 0.1988 - val_loss: 0.4266
# Epoch 5/50
#  - 0s - loss: 0.1833 - val_loss: 0.4407
# Epoch 6/50
#  - 0s - loss: 0.1702 - val_loss: 0.4539
# Epoch 7/50
#  - 0s - loss: 0.1584 - val_loss: 0.4663
# Epoch 8/50
#  - 0s - loss: 0.1474 - val_loss: 0.4780
# Epoch 9/50
#  - 0s - loss: 0.1373 - val_loss: 0.4891
# Epoch 10/50
#  - 0s - loss: 0.1281 - val_loss: 0.4994
# Epoch 11/50
#  - 0s - loss: 0.1199 - val_loss: 0.5090
# Epoch 12/50
#  - 0s - loss: 0.1124 - val_loss: 0.5179
# Epoch 13/50
#  - 0s - loss: 0.1056 - val_loss: 0.5262
# Epoch 14/50
#  - 0s - loss: 0.0993 - val_loss: 0.5339
# Epoch 15/50
#  - 0s - loss: 0.0937 - val_loss: 0.5411
# Epoch 16/50
#  - 0s - loss: 0.0887 - val_loss: 0.5477
# Epoch 17/50
#  - 0s - loss: 0.0844 - val_loss: 0.5537
# Epoch 18/50
#  - 0s - loss: 0.0808 - val_loss: 0.5590
# Epoch 19/50
#  - 0s - loss: 0.0776 - val_loss: 0.5640
# Epoch 20/50
#  - 0s - loss: 0.0748 - val_loss: 0.5687
# Epoch 21/50
#  - 0s - loss: 0.0721 - val_loss: 0.5732
# Epoch 22/50
#  - 0s - loss: 0.0696 - val_loss: 0.5776
# Epoch 23/50
#  - 0s - loss: 0.0672 - val_loss: 0.5817
# Epoch 24/50
#  - 0s - loss: 0.0651 - val_loss: 0.5854
# Epoch 25/50
#  - 0s - loss: 0.0632 - val_loss: 0.5888
# Epoch 26/50
#  - 0s - loss: 0.0617 - val_loss: 0.5919
# Epoch 27/50
#  - 0s - loss: 0.0604 - val_loss: 0.5947
# Epoch 28/50
#  - 0s - loss: 0.0593 - val_loss: 0.5973
# Epoch 29/50
#  - 0s - loss: 0.0584 - val_loss: 0.5996
# Epoch 30/50
#  - 0s - loss: 0.0576 - val_loss: 0.6016
# Epoch 31/50
#  - 0s - loss: 0.0570 - val_loss: 0.6034
# Epoch 32/50
#  - 0s - loss: 0.0565 - val_loss: 0.6050
# Epoch 33/50
#  - 0s - loss: 0.0561 - val_loss: 0.6064
# Epoch 34/50
#  - 0s - loss: 0.0558 - val_loss: 0.6077
# Epoch 35/50
#  - 0s - loss: 0.0555 - val_loss: 0.6088
# Epoch 36/50
#  - 0s - loss: 0.0553 - val_loss: 0.6097
# Epoch 37/50
#  - 0s - loss: 0.0552 - val_loss: 0.6105
# Epoch 38/50
#  - 0s - loss: 0.0551 - val_loss: 0.6112
# Epoch 39/50
#  - 0s - loss: 0.0550 - val_loss: 0.6118
# Epoch 40/50
#  - 0s - loss: 0.0549 - val_loss: 0.6123
# Epoch 41/50
#  - 0s - loss: 0.0548 - val_loss: 0.6128
# Epoch 42/50
#  - 0s - loss: 0.0548 - val_loss: 0.6132
# Epoch 43/50
#  - 0s - loss: 0.0548 - val_loss: 0.6135
# Epoch 44/50
#  - 0s - loss: 0.0547 - val_loss: 0.6138
# Epoch 45/50
#  - 0s - loss: 0.0547 - val_loss: 0.6141
# Epoch 46/50
#  - 0s - loss: 0.0547 - val_loss: 0.6144
# Epoch 47/50
#  - 0s - loss: 0.0547 - val_loss: 0.6146
# Epoch 48/50
#  - 0s - loss: 0.0547 - val_loss: 0.6147
# Epoch 49/50
#  - 0s - loss: 0.0547 - val_loss: 0.6149
# Epoch 50/50
#  - 0s - loss: 0.0547 - val_loss: 0.6150
# Epoch 1/50
#  - 2s - loss: 0.3295
# Epoch 2/50
#  - 0s - loss: 0.3004
# Epoch 3/50
#  - 0s - loss: 0.2813
# Epoch 4/50
#  - 0s - loss: 0.2654
# Epoch 5/50
#  - 0s - loss: 0.2400
# Epoch 6/50
#  - 0s - loss: 0.2061
# Epoch 7/50
#  - 0s - loss: 0.1805
# Epoch 8/50
#  - 0s - loss: 0.1571
# Epoch 9/50
#  - 0s - loss: 0.1400
# Epoch 10/50
#  - 0s - loss: 0.1278
# Epoch 11/50
#  - 0s - loss: 0.1175
# Epoch 12/50
#  - 0s - loss: 0.1105
# Epoch 13/50
#  - 0s - loss: 0.1036
# Epoch 14/50
#  - 0s - loss: 0.0973
# Epoch 15/50
#  - 0s - loss: 0.0893
# Epoch 16/50
#  - 0s - loss: 0.0857
# Epoch 17/50
#  - 0s - loss: 0.0783
# Epoch 18/50
#  - 0s - loss: 0.0745
# Epoch 19/50
#  - 0s - loss: 0.0708
# Epoch 20/50
#  - 0s - loss: 0.0676
# Epoch 21/50
#  - 0s - loss: 0.0645
# Epoch 22/50
#  - 0s - loss: 0.0615
# Epoch 23/50
#  - 0s - loss: 0.0588
# Epoch 24/50
#  - 0s - loss: 0.0561
# Epoch 25/50
#  - 0s - loss: 0.0542
# Epoch 26/50
#  - 0s - loss: 0.0518
# Epoch 27/50
#  - 0s - loss: 0.0505
# Epoch 28/50
#  - 0s - loss: 0.0486
# Epoch 29/50
#  - 0s - loss: 0.0490
# Epoch 30/50
#  - 0s - loss: 0.0501
# Epoch 31/50
#  - 0s - loss: 0.0527
# Epoch 32/50
#  - 0s - loss: 0.0474
# Epoch 33/50
#  - 0s - loss: 0.0503
# Epoch 34/50
#  - 0s - loss: 0.0468
# Epoch 35/50
#  - 0s - loss: 0.0507
# Epoch 36/50
#  - 0s - loss: 0.0452
# Epoch 37/50
#  - 0s - loss: 0.0476
# Epoch 38/50
#  - 0s - loss: 0.0449
# Epoch 39/50
#  - 0s - loss: 0.0485
# Epoch 40/50
#  - 0s - loss: 0.0447
# Epoch 41/50
#  - 0s - loss: 0.0487
# Epoch 42/50
#  - 0s - loss: 0.0439
# Epoch 43/50
#  - 0s - loss: 0.0472
# Epoch 44/50
#  - 0s - loss: 0.0439
# Epoch 45/50
#  - 0s - loss: 0.0474
# Epoch 46/50
#  - 0s - loss: 0.0435
# Epoch 47/50
#  - 0s - loss: 0.0470
# Epoch 48/50
#  - 0s - loss: 0.0432
# Epoch 49/50
#  - 0s - loss: 0.0464
# Epoch 50/50
#  - 0s - loss: 0.0430
# Starting model for:  XLY
# Train on 2577 samples, validate on 1000 samples
# Epoch 1/50
#  - 2s - loss: 0.2675 - val_loss: 0.3414
# Epoch 2/50
#  - 0s - loss: 0.1774 - val_loss: 0.4050
# Epoch 3/50
#  - 0s - loss: 0.1270 - val_loss: 0.4260
# Epoch 4/50
#  - 0s - loss: 0.1070 - val_loss: 0.4372
# Epoch 5/50
#  - 0s - loss: 0.0964 - val_loss: 0.4461
# Epoch 6/50
#  - 0s - loss: 0.0891 - val_loss: 0.4538
# Epoch 7/50
#  - 0s - loss: 0.0837 - val_loss: 0.4605
# Epoch 8/50
#  - 0s - loss: 0.0796 - val_loss: 0.4663
# Epoch 9/50
#  - 0s - loss: 0.0764 - val_loss: 0.4714
# Epoch 10/50
#  - 0s - loss: 0.0739 - val_loss: 0.4760
# Epoch 11/50
#  - 0s - loss: 0.0718 - val_loss: 0.4802
# Epoch 12/50
#  - 0s - loss: 0.0699 - val_loss: 0.4841
# Epoch 13/50
#  - 0s - loss: 0.0683 - val_loss: 0.4877
# Epoch 14/50
#  - 0s - loss: 0.0669 - val_loss: 0.4912
# Epoch 15/50
#  - 0s - loss: 0.0655 - val_loss: 0.4944
# Epoch 16/50
#  - 0s - loss: 0.0644 - val_loss: 0.4972
# Epoch 17/50
#  - 0s - loss: 0.0635 - val_loss: 0.4997
# Epoch 18/50
#  - 0s - loss: 0.0627 - val_loss: 0.5017
# Epoch 19/50
#  - 0s - loss: 0.0622 - val_loss: 0.5033
# Epoch 20/50
#  - 0s - loss: 0.0619 - val_loss: 0.5046
# Epoch 21/50
#  - 0s - loss: 0.0617 - val_loss: 0.5056
# Epoch 22/50
#  - 0s - loss: 0.0616 - val_loss: 0.5064
# Epoch 23/50
#  - 0s - loss: 0.0615 - val_loss: 0.5070
# Epoch 24/50
#  - 0s - loss: 0.0614 - val_loss: 0.5075
# Epoch 25/50
#  - 0s - loss: 0.0613 - val_loss: 0.5079
# Epoch 26/50
#  - 0s - loss: 0.0613 - val_loss: 0.5082
# Epoch 27/50
#  - 0s - loss: 0.0613 - val_loss: 0.5084
# Epoch 28/50
#  - 0s - loss: 0.0612 - val_loss: 0.5086
# Epoch 29/50
#  - 0s - loss: 0.0612 - val_loss: 0.5087
# Epoch 30/50
#  - 0s - loss: 0.0612 - val_loss: 0.5089
# Epoch 31/50
#  - 0s - loss: 0.0612 - val_loss: 0.5089
# Epoch 32/50
#  - 0s - loss: 0.0612 - val_loss: 0.5090
# Epoch 33/50
#  - 0s - loss: 0.0612 - val_loss: 0.5091
# Epoch 34/50
#  - 0s - loss: 0.0612 - val_loss: 0.5092
# Epoch 35/50
#  - 0s - loss: 0.0612 - val_loss: 0.5092
# Epoch 36/50
#  - 0s - loss: 0.0611 - val_loss: 0.5093
# Epoch 37/50
#  - 0s - loss: 0.0611 - val_loss: 0.5093
# Epoch 38/50
#  - 0s - loss: 0.0611 - val_loss: 0.5093
# Epoch 39/50
#  - 0s - loss: 0.0611 - val_loss: 0.5093
# Epoch 40/50
#  - 0s - loss: 0.0610 - val_loss: 0.5093
# Epoch 41/50
#  - 0s - loss: 0.0610 - val_loss: 0.5093
# Epoch 42/50
#  - 0s - loss: 0.0609 - val_loss: 0.5093
# Epoch 43/50
#  - 0s - loss: 0.0608 - val_loss: 0.5092
# Epoch 44/50
#  - 0s - loss: 0.0606 - val_loss: 0.5090
# Epoch 45/50
#  - 0s - loss: 0.0602 - val_loss: 0.5082
# Epoch 46/50
#  - 0s - loss: 0.0589 - val_loss: 0.5039
# Epoch 47/50
#  - 0s - loss: 0.0533 - val_loss: 0.4560
# Epoch 48/50
#  - 0s - loss: 0.0632 - val_loss: 0.4887
# Epoch 49/50
#  - 0s - loss: 0.0520 - val_loss: 0.4515
# Epoch 50/50
#  - 0s - loss: 0.0523 - val_loss: 0.4204
# Epoch 1/50
#  - 3s - loss: 0.2893
# Epoch 2/50
#  - 0s - loss: 0.2649
# Epoch 3/50
#  - 0s - loss: 0.2473
# Epoch 4/50
#  - 0s - loss: 0.2320
# Epoch 5/50
#  - 0s - loss: 0.2097
# Epoch 6/50
#  - 0s - loss: 0.1717
# Epoch 7/50
#  - 0s - loss: 0.1556
# Epoch 8/50
#  - 0s - loss: 0.1312
# Epoch 9/50
#  - 0s - loss: 0.1217
# Epoch 10/50
#  - 0s - loss: 0.1122
# Epoch 11/50
#  - 0s - loss: 0.1045
# Epoch 12/50
#  - 0s - loss: 0.0976
# Epoch 13/50
#  - 0s - loss: 0.0923
# Epoch 14/50
#  - 0s - loss: 0.0872
# Epoch 15/50
#  - 0s - loss: 0.0826
# Epoch 16/50
#  - 0s - loss: 0.0782
# Epoch 17/50
#  - 0s - loss: 0.0740
# Epoch 18/50
#  - 0s - loss: 0.0701
# Epoch 19/50
#  - 0s - loss: 0.0667
# Epoch 20/50
#  - 0s - loss: 0.0636
# Epoch 21/50
#  - 0s - loss: 0.0607
# Epoch 22/50
#  - 0s - loss: 0.0579
# Epoch 23/50
#  - 0s - loss: 0.0555
# Epoch 24/50
#  - 0s - loss: 0.0534
# Epoch 25/50
#  - 0s - loss: 0.0513
# Epoch 26/50
#  - 0s - loss: 0.0499
# Epoch 27/50
#  - 0s - loss: 0.0488
# Epoch 28/50
#  - 0s - loss: 0.0480
# Epoch 29/50
#  - 0s - loss: 0.0474
# Epoch 30/50
#  - 0s - loss: 0.0468
# Epoch 31/50
#  - 0s - loss: 0.0462
# Epoch 32/50
#  - 0s - loss: 0.0458
# Epoch 33/50
#  - 0s - loss: 0.0453
# Epoch 34/50
#  - 0s - loss: 0.0448
# Epoch 35/50
#  - 0s - loss: 0.0444
# Epoch 36/50
#  - 0s - loss: 0.0440
# Epoch 37/50
#  - 0s - loss: 0.0437
# Epoch 38/50
#  - 0s - loss: 0.0433
# Epoch 39/50
#  - 0s - loss: 0.0430
# Epoch 40/50
#  - 0s - loss: 0.0427
# Epoch 41/50
#  - 0s - loss: 0.0424
# Epoch 42/50
#  - 0s - loss: 0.0426
# Epoch 43/50
#  - 0s - loss: 0.0419
# Epoch 44/50
#  - 0s - loss: 0.0417
# Epoch 45/50
#  - 0s - loss: 0.0424
# Epoch 46/50
#  - 0s - loss: 0.0417
# Epoch 47/50
#  - 0s - loss: 0.0416
# Epoch 48/50
#  - 0s - loss: 0.0403
# Epoch 49/50
#  - 0s - loss: 0.0419
# Epoch 50/50
#  - 0s - loss: 0.0399

# %%
def end_rank_log(output):
    sectors = ['XLB', 'XLE', 'XLF', 'XLI', 'XLK', 'XLU', 'XLV', 'XLY']
    sector_names = ['Materials', 'Energy', 'Financials', 'Industrials', 'Technology',
                   'Utilities', 'Health Care', 'Consumer Discretionary']
    output_l = list()
    for item in output:
        val = sum(item)
        output_l.append((val))
            
    #turn each into a dataframe
    returns_df = pd.DataFrame({'sector': sector_names, 'sector_symbol':sectors, 'sum log(% returns)':output_l})
    #sort
    returns_df_sorted = returns_df.sort_values(by='sum log(% returns)', ascending = False).reset_index(drop=True)
    print('Reccomended investments in ', returns_df_sorted.iloc[0,0], 'sector')
    print(returns_df_sorted)
    return returns_df_sorted

# %% [markdown]
# # Final Output rankings

# %%
lstm_output = end_rank_log(returns_list)
# Out:
# Reccomended investments in  Financials sector
#                    sector sector_symbol  sum log(% returns)
# 0              Financials           XLF           74.118410
# 1             Industrials           XLI           56.435593
# 2               Utilities           XLU           48.567430
# 3                  Energy           XLE           48.164602
# 4               Materials           XLB           43.023235
# 5  Consumer Discretionary           XLY           40.756713
# 6             Health Care           XLV           35.983836
# 7              Technology           XLK           25.525356
